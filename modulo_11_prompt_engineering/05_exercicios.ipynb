# %% [markdown]
# # Exercícios Práticos de Prompt Engineering
#
# Este notebook contém exercícios práticos para aplicar os conceitos aprendidos no módulo.
#
# ## Conteúdo
# 1. Exercícios de Fundamentos
# 2. Desafios de Técnicas Avançadas
# 3. Projetos Práticos
# 4. Avaliação e Feedback
# 5. Recursos Adicionais

# %% [markdown]
# # Exercícios de Prompt Engineering
#
# ## Exercício 1: Fundamentos
# Melhore os seguintes prompts básicos:
#
# ### 1.1 Descrição de Produto
# ```
# # Prompt Original
# Descreva um smartphone para venda online.
#
# # Seu Desafio
# Crie um prompt mais estruturado que inclua:
# - Contexto apropriado
# - Especificações do produto
# - Formato desejado
# - Restrições e requisitos
# - Elementos de marketing
# ```
#
# ### 1.2 Explicação Científica
# ```
# # Prompt Original
# Explique o que é fotossíntese.
#
# # Seu Desafio
# Desenvolva um prompt que:
# - Defina o nível de complexidade
# - Inclua analogias
# - Solicite exemplos práticos
# - Especifique o público-alvo
# ```
#
# ## Exercício 2: Técnicas Avançadas
#
# ### 2.1 Chain-of-Thought
# ```
# # Problema
# Crie um prompt usando CoT para resolver:
# "Em uma festa, 1/3 dos convidados são crianças, 1/2 são adultos, e o resto são idosos.
# Se há 12 idosos, quantos convidados há no total?"
# ```
#
# ### 2.2 Few-Shot Learning
# ```
# # Tarefa
# Desenvolva um prompt com exemplos para classificar emails em categorias:
# - Urgente
# - Importante
# - Rotina
# - Spam
# ```
#
# ## Dicas para os Exercícios
# 1. Use os princípios aprendidos
# 2. Teste diferentes versões
# 3. Compare os resultados
# 4. Documente as melhorias

# %% [markdown]
# ## Exercícios de Prompt Engineering
#
# ### Exercício 1: Fundamentos
# Crie prompts para as seguintes tarefas:
# 1. Gerar uma descrição de produto para uma loja online
# 2. Explicar um conceito científico para uma criança
# 3. Criar um resumo de um artigo técnico
#
# ### Exercício 2: Técnicas Avançadas
# Aplique técnicas avançadas para:
# 1. Resolver um problema matemático usando Chain-of-Thought
# 2. Criar um assistente virtual usando Role Prompting
# 3. Melhorar um texto usando Iterative Refinement
#
# ### Exercício 3: Aplicações Práticas
# Desenvolva prompts para:
# 1. Análise de sentimentos em reviews
# 2. Geração de conteúdo para redes sociais
# 3. Tradução e localização de textos
#
# ### Exercício 4: Otimização
# Melhore os seguintes prompts:
# 1. "Escreva um email"
# 2. "Me ajude com Python"
# 3. "Faça um resumo"

# %%
# Configuração do ambiente para os exercícios
# %pip install openai python-dotenv transformers

import os
from dotenv import load_dotenv
from transformers import pipeline

# Carregando variáveis de ambiente
load_dotenv()

# Configurando o modelo
generator = pipeline('text-generation', model='gpt2')

# Função auxiliar para testar prompts
def testar_prompt(prompt, max_length=200):
    print(f"\nPrompt testado:\n{prompt}\n")
    print("Resultado:")
    resultado = generator(prompt, max_length=max_length, num_return_sequences=1)
    print(resultado[0]['generated_text'])
    print("\n" + "="*50 + "\n")

# %% [markdown]
# ### Exercício 1.1: Descrição de Produto
#
# Melhore o seguinte prompt básico para gerar uma descrição mais completa e persuasiva de um produto:
#
# #### Prompt Básico
# ```
# Descreva um smartphone para venda online.
# ```
#
# #### Sua Tarefa
# Crie um prompt mais estruturado que inclua:
# - Contexto apropriado
# - Especificações do produto
# - Formato desejado
# - Restrições e requisitos
# - Elementos de marketing
#
# Use o espaço abaixo para sua solução e depois compare os resultados.

# %% [markdown]
# ### Exemplo de Solução
#
# Um prompt melhorado poderia ser:
#
# > **Contexto:**
# > Você é um copywriter especializado em descrições de produtos tecnológicos.
# >
# > **Tarefa:**
# > Crie uma descrição persuasiva para um smartphone de última geração.
# >
# > **Especificações do produto:**
# > - Tela AMOLED de 6.7"
# > - Câmera principal de 108MP
# > - Processador octa-core
# > - 8GB RAM, 256GB armazenamento
# > - Bateria 5000mAh
# >
# > **Formato desejado:**
# > 1. Título chamativo
# > 2. Parágrafo introdutório envolvente
# > 3. Lista de características principais
# > 4. Benefícios para o usuário
# > 5. Call-to-action
# >
# > **Restrições:**
# > - Tom profissional mas acessível
# > - Máximo 300 palavras
# > - Destaque recursos únicos
# > - Inclua palavras-chave para SEO
#
# Este prompt é melhor porque:
# 1. Fornece contexto claro
# 2. Inclui especificações detalhadas
# 3. Define estrutura específica
# 4. Estabelece restrições claras
# 5. Considera aspectos de marketing
#
# Vamos testar ambos os prompts e comparar os resultados:

# %% [raw]
# # Desafios de Técnicas Avançadas
#
# ## Desafio 1: Chain-of-Thought Complexo
# Crie um prompt CoT para resolver este problema multi-etapas:
#
# ```
# "Uma empresa tem 3 departamentos: Vendas (40 funcionários), Marketing (25 funcionários)
# e TI (15 funcionários). A empresa decidiu dar um bônus de R$ 2.000 para cada funcionário
# de Vendas, R$ 1.500 para Marketing e R$ 2.500 para TI. Além disso, haverá um bônus
# adicional de 10% do salário médio de cada departamento (Vendas: R$ 4.000, Marketing:
# R$ 3.500, TI: R$ 6.000). Qual será o gasto total da empresa com bônus?"
# ```
#
# **Seu prompt deve:**
# - Quebrar o problema em etapas claras
# - Solicitar verificação de cada cálculo
# - Pedir resumo final organizado
#
# ## Desafio 2: Few-Shot para Classificação Complexa
# Desenvolva um prompt few-shot para classificar comentários de produtos em múltiplas dimensões:
#
# **Categorias:**
# - Sentimento: Positivo/Negativo/Neutro/Misto
# - Aspecto: Qualidade/Preço/Atendimento/Entrega/Design
# - Urgência: Alta/Média/Baixa
# - Ação recomendada: Responder/Investigar/Arquivar
#
# **Inclua 3 exemplos completos e teste com:**
# - "O produto chegou rápido mas veio com defeito, preciso de troca urgente!"
# - "Preço justo, qualidade ok, nada excepcional."
# - "Atendimento péssimo, ninguém resolve meu problema há uma semana!"
#
# ## Desafio 3: Role Prompting Avançado
# Crie um sistema de role prompting para um assistente de vendas que deve:
#
# 1. **Adaptar-se ao perfil do cliente:**
#    - Técnico (foca em especificações)
#    - Executivo (foca em ROI e resultados)
#    - Usuário final (foca em facilidade de uso)
#
# 2. **Manter consistência:**
#    - Tom profissional mas amigável
#    - Sempre oferecer próximos passos
#    - Fazer perguntas qualificadoras
#
# 3. **Seguir processo de vendas:**
#    - Descoberta de necessidades
#    - Apresentação de soluções
#    - Tratamento de objeções
#    - Fechamento

# %% [raw]
# # Projetos Práticos
#
# ## Projeto 1: Sistema de Atendimento ao Cliente
# Desenvolva um sistema completo de prompts para atendimento ao cliente de uma empresa de software.
#
# ### Requisitos:
# 1. **Prompt de Triagem Inicial**
#    - Classifica tipo de solicitação
#    - Identifica urgência
#    - Direciona para departamento correto
#
# 2. **Prompts Especializados**
#    - Suporte técnico
#    - Vendas
#    - Financeiro
#    - Cancelamento
#
# 3. **Prompt de Escalação**
#    - Quando transferir para humano
#    - Como resumir o histórico
#    - Informações necessárias
#
# ### Entregáveis:
# - Conjunto de prompts documentados
# - Fluxo de decisão
# - Exemplos de uso
# - Métricas de avaliação
#
# ## Projeto 2: Gerador de Conteúdo para E-commerce
# Crie um sistema de prompts para gerar descrições de produtos automaticamente.
#
# ### Componentes:
# 1. **Análise de Categoria**
#    - Identifica tipo de produto
#    - Define atributos relevantes
#    - Estabelece tom apropriado
#
# 2. **Geração de Conteúdo**
#    - Título otimizado para SEO
#    - Descrição persuasiva
#    - Especificações técnicas
#    - Benefícios para o cliente
#
# 3. **Adaptação por Canal**
#    - Site principal
#    - Marketplace
#    - Redes sociais
#    - E-mail marketing
#
# ### Teste com:
# - Eletrônicos
# - Roupas
# - Casa e jardim
# - Livros
#
# ## Projeto 3: Assistente de Aprendizagem Personalizado
# Desenvolva prompts para um tutor virtual que se adapta ao estilo de aprendizagem do aluno.
#
# ### Funcionalidades:
# 1. **Avaliação Inicial**
#    - Identifica nível de conhecimento
#    - Determina estilo de aprendizagem
#    - Define objetivos
#
# 2. **Explicações Adaptativas**
#    - Visual (diagramas, analogias)
#    - Auditivo (explicações verbais)
#    - Cinestésico (exercícios práticos)
#
# 3. **Feedback Personalizado**
#    - Identifica pontos fortes
#    - Sugere melhorias
#    - Ajusta dificuldade
#
# ### Domínios de Teste:
# - Matemática básica
# - Programação
# - História
# - Idiomas

# %% [raw]
# # Avaliação e Feedback
#
# ## Critérios de Avaliação
#
# ### 1. Qualidade Técnica (40%)
# - **Estrutura do Prompt (10%)**
#   - Contexto claro e adequado
#   - Instruções específicas
#   - Formato bem definido
#   - Restrições apropriadas
#
# - **Aplicação de Técnicas (15%)**
#   - Uso correto de Chain-of-Thought
#   - Implementação efetiva de Few-Shot
#   - Role Prompting bem definido
#   - Refinamento iterativo
#
# - **Otimização (15%)**
#   - Eficiência no uso de tokens
#   - Clareza e concisão
#   - Estrutura lógica
#
# ### 2. Funcionalidade (30%)
# - **Efetividade (15%)**
#   - Atinge o objetivo proposto
#   - Produz resultados consistentes
#   - Resolve o problema corretamente
#
# - **Robustez (15%)**
#   - Funciona com diferentes inputs
#   - Trata casos extremos
#   - Mantém qualidade ao longo do tempo
#
# ### 3. Usabilidade (20%)
# - **Clareza (10%)**
#   - Fácil de entender
#   - Instruções não ambíguas
#   - Linguagem apropriada
#
# - **Manutenibilidade (10%)**
#   - Bem documentado
#   - Fácil de modificar
#   - Versionamento claro
#
# ### 4. Inovação e Criatividade (10%)
# - Soluções originais
# - Uso criativo de técnicas
# - Abordagens inovadoras
#
# ## Formulário de Auto-Avaliação
#
# Para cada exercício/projeto, responda:
#
# 1. **Qual foi o maior desafio enfrentado?**
# 2. **Que técnicas funcionaram melhor?**
# 3. **O que você faria diferente?**
# 4. **Quais melhorias ainda são necessárias?**
# 5. **Como você mediria o sucesso deste prompt?**
#
# ## Peer Review
#
# Troque seus prompts com colegas e avalie:
#
# ### Checklist de Revisão:
# - [ ] O objetivo está claro?
# - [ ] As instruções são específicas?
# - [ ] O contexto é adequado?
# - [ ] O formato está bem definido?
# - [ ] Há exemplos suficientes?
# - [ ] As restrições fazem sentido?
# - [ ] O prompt é eficiente?
# - [ ] Considera aspectos éticos?
#
# ### Feedback Construtivo:
# - **Pontos Fortes:** O que funcionou bem
# - **Melhorias:** Sugestões específicas
# - **Questões:** Dúvidas ou ambiguidades
# - **Ideias:** Sugestões criativas

# %% [raw]
# # Recursos Adicionais
#
# ## Ferramentas Recomendadas
#
# ### 1. Plataformas de Teste
# - **OpenAI Playground**: Teste rápido de prompts
# - **Anthropic Claude**: Interface para experimentação
# - **Hugging Face Spaces**: Modelos open source
# - **Colab/Jupyter**: Ambiente de desenvolvimento
#
# ### 2. Bibliotecas Python
# ```python
# # Principais bibliotecas para prompt engineering
# pip install openai
# pip install anthropic
# pip install transformers
# pip install langchain
# pip install guidance
# ```
#
# ### 3. Ferramentas de Monitoramento
# - **Weights & Biases**: Tracking de experimentos
# - **MLflow**: Gestão de modelos
# - **Prometheus**: Métricas de produção
# - **Grafana**: Dashboards de monitoramento
#
# ## Templates Úteis
#
# ### 1. Template Base para Prompts
# ```
# # Identificação
# ID: [prompt-id]
# Versão: [v1.0]
# Data: [YYYY-MM-DD]
#
# # Contexto
# Papel: [definir papel do assistente]
# Situação: [contexto da tarefa]
# Público: [quem vai usar/receber]
#
# # Tarefa
# Objetivo: [o que deve ser feito]
# Entrada: [formato dos dados de entrada]
# Saída: [formato esperado da resposta]
#
# # Restrições
# - [limitação 1]
# - [limitação 2]
# - [limitação 3]
#
# # Exemplos
# [incluir exemplos quando apropriado]
# ```
#
# ### 2. Template para Documentação
# ```
# # Prompt Documentation
#
# ## Visão Geral
# - **Propósito**: [para que serve]
# - **Caso de Uso**: [quando usar]
# - **Limitações**: [o que não faz]
#
# ## Implementação
# - **Modelo Recomendado**: [GPT-4, Claude, etc.]
# - **Configurações**: [temperature, max_tokens, etc.]
# - **Dependências**: [bibliotecas necessárias]
#
# ## Métricas
# - **Sucesso**: [como medir]
# - **Benchmark**: [valores de referência]
# - **Monitoramento**: [o que acompanhar]
#
# ## Changelog
# - **v1.0**: [mudanças iniciais]
# - **v1.1**: [melhorias implementadas]
# ```
#
# ## Leituras Recomendadas
#
# ### Artigos Fundamentais
# 1. "Chain-of-Thought Prompting Elicits Reasoning in Large Language Models" (Wei et al., 2022)
# 2. "Training language models to follow instructions with human feedback" (Ouyang et al., 2022)
# 3. "Constitutional AI: Harmlessness from AI Feedback" (Bai et al., 2022)
#
# ### Blogs e Recursos Online
# - OpenAI Blog: Prompt Engineering Guide
# - Anthropic Research Papers
# - Hugging Face NLP Course
# - Papers With Code: Prompt Engineering
#
# ### Comunidades
# - Reddit: r/MachineLearning, r/PromptEngineering
# - Discord: OpenAI Community
# - Twitter: #PromptEngineering
# - GitHub: Awesome Prompt Engineering
#
# ## Próximos Passos
#
# ### Aprofundamento
# 1. **Especialização por Domínio**
#    - Prompts médicos
#    - Prompts jurídicos
#    - Prompts educacionais
#    - Prompts técnicos
#
# 2. **Técnicas Avançadas**
#    - Tree of Thoughts
#    - Self-Consistency
#    - Program-aided Language Models
#    - Retrieval-Augmented Generation
#
# 3. **Produção e Escala**
#    - MLOps para prompts
#    - A/B testing
#    - Monitoramento contínuo
#    - Versionamento de prompts
#
# ### Certificações e Cursos
# - OpenAI API Certification
# - Coursera: Natural Language Processing
# - edX: Introduction to Artificial Intelligence
# - Udacity: AI Programming Nanodegree

# %% [markdown]
# ### Exemplo de Solução
#
# Um prompt melhorado poderia ser:
#
# ```
# Contexto: Você é um copywriter especializado em descrições de produtos tecnológicos.
#
# Tarefa: Crie uma descrição persuasiva para um smartphone de última geração.
#
# Especificações do produto:
# - Tela AMOLED de 6.7"
# - Câmera principal de 108MP
# - Processador octa-core
# - 8GB RAM, 256GB armazenamento
# - Bateria 5000mAh
#
# Formato desejado:
# 1. Título chamativo
# 2. Parágrafo introdutório envolvente
# 3. Lista de características principais
# 4. Benefícios para o usuário
# 5. Call-to-action
#
# Restrições:
# - Tom profissional mas acessível
# - Máximo 300 palavras
# - Destaque recursos únicos
# - Inclua palavras-chave para SEO
# ```
#
# Este prompt é melhor porque:
# 1. Fornece contexto claro
# 2. Inclui especificações detalhadas
# 3. Define estrutura específica
# 4. Estabelece restrições claras
# 5. Considera aspectos de marketing
#
# Vamos testar ambos os prompts e comparar os resultados:

# %%
# Exercício 1.1: Descrição de Produto
# Seu desafio: Melhorar este prompt básico para gerar uma descrição mais completa e persuasiva

prompt_basico = "Descreva um smartphone para venda online."

# Espaço para sua solução
seu_prompt = """
# Seu prompt melhorado aqui
"""

# Teste ambos os prompts para comparar
print("Resultado do prompt básico:")
testar_prompt(prompt_basico)

print("Resultado do seu prompt:")
testar_prompt(seu_prompt)

# %% [markdown]
# ### Exemplo de Solução para Exercício 1.1
#
# Um prompt melhorado poderia ser:
#
# ```python
# prompt_melhorado = """
# Contexto: Você é um copywriter especializado em descrições de produtos tecnológicos.
#
# Tarefa: Crie uma descrição persuasiva para um smartphone de última geração.
#
# Especificações do produto:
# - Tela AMOLED de 6.7"
# - Câmera principal de 108MP
# - Processador octa-core
# - 8GB RAM, 256GB armazenamento
# - Bateria 5000mAh
#
# Formato desejado:
# 1. Título chamativo
# 2. Parágrafo introdutório envolvente
# 3. Lista de características principais
# 4. Benefícios para o usuário
# 5. Call-to-action
#
# Restrições:
# - Tom profissional mas acessível
# - Máximo 300 palavras
# - Destaque recursos únicos
# - Inclua palavras-chave para SEO
# """
# ```
#
# Este prompt é melhor porque:
# 1. Fornece contexto claro
# 2. Inclui especificações detalhadas
# 3. Define estrutura específica
# 4. Estabelece restrições claras
# 5. Considera aspectos de marketing
