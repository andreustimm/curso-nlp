# %% [raw]
# # 📚 Curso de NLP - Índice de Notebooks
#
# ## 🎯 Visão Geral do Curso
#
# Este curso completo de **Processamento de Linguagem Natural (NLP)** oferece uma jornada progressiva desde conceitos fundamentais até aplicações avançadas com modelos state-of-the-art.
#
# ### 📊 Estatísticas do Curso
# - **10 Módulos Completos** - Do básico ao avançado
# - **60-80 horas** de conteúdo prático
# - **Notebooks Interativos** - Código executável
# - **5 Projetos End-to-End** - Portfolio profissional
# - **Múltiplas Linguagens** - Python, TensorFlow, PyTorch
# - **Dados Reais** - Datasets práticos inclusos
#
# ---
#
# ## 📖 Módulos e Notebooks
#
# ### 🔰 **Módulo 1: Fundamentos de NLP**
# 📁 `modulo_01_fundamentos/01_introducao_nlp.ipynb`
#
# **🎯 Objetivos:**
# - Compreender conceitos básicos de NLP
# - Explorar aplicações práticas
# - Comparar bibliotecas (NLTK, spaCy, TextBlob)
# - Implementar pipeline básico
#
# **🛠 Conteúdo Prático:**
# - História e evolução do NLP
# - Desafios fundamentais
# - Comparação de ferramentas
# - Análise estatística básica
# - Primeiros experimentos
#
# ---
#
# ### 🧹 **Módulo 2: Pré-processamento de Texto**
# 📁 `modulo_02_preprocessamento/02_preprocessamento_texto.ipynb`
#
# **🎯 Objetivos:**
# - Dominar técnicas de limpeza
# - Implementar tokenização eficaz
# - Aplicar stemming e lemmatização
# - Normalizar textos multilíngues
#
# **🛠 Conteúdo Prático:**
# - Limpeza de URLs, emails, caracteres especiais
# - Tokenização com NLTK e spaCy
# - Remoção inteligente de stopwords
# - Stemming vs Lemmatização comparativo
# - Pipeline completo de pré-processamento
#
# ---
#
# ### 📊 **Módulo 3: Análise Estatística**
# 📁 `modulo_03_analise_estatistica/03_analise_estatistica.ipynb`
#
# **🎯 Objetivos:**
# - Implementar análise de frequência
# - Verificar Lei de Zipf
# - Calcular n-gramas e colocações
# - Medir similaridade textual
#
# **🛠 Conteúdo Prático:**
# - Distribuições de frequência
# - Lei de Zipf com visualizações
# - Bigramas e trigramas
# - Análise de colocações
# - Métricas de similaridade
# - Análise de corpus completa
#
# ---
#
# ### 🔤 **Módulo 4: Representação de Texto**
# 📁 `modulo_04_representacao/04_representacao_texto.ipynb`
#
# **🎯 Objetivos:**
# - Implementar Bag of Words
# - Calcular TF-IDF detalhadamente
# - Treinar word embeddings
# - Aplicar redução de dimensionalidade
#
# **🛠 Conteúdo Prático:**
# - BoW: Binary, Count, Normalized
# - TF-IDF teoria e implementação
# - Word2Vec e FastText training
# - PCA, t-SNE, UMAP para visualização
# - Avaliação de embeddings
# - Busca semântica prática
#
# ---
#
# ### 🎯 **Módulo 5: Classificação de Texto**
# 📁 `modulo_05_classificacao/05_classificacao_texto.ipynb`
#
# **🎯 Objetivos:**
# - Implementar algoritmos clássicos
# - Comparar Naive Bayes, SVM, Logistic Regression
# - Usar ensemble methods
# - Otimizar hiperparâmetros
#
# **🛠 Conteúdo Prático:**
# - Análise de sentimentos completa
# - Múltiplos algoritmos comparados
# - Grid Search e Cross-validation
# - Tratamento de dados desbalanceados
# - Métricas de avaliação detalhadas
# - Pipeline de produção
#
# ---
#
# ### 🔗 **Módulo 6: Modelos de Sequência**
# 📁 `modulo_06_modelos_sequencia/06_modelos_sequencia.ipynb`
#
# **🎯 Objetivos:**
# - Implementar modelos de n-gramas
# - Aplicar Hidden Markov Models
# - Usar Conditional Random Fields
# - Realizar POS tagging e NER
#
# **🛠 Conteúdo Prático:**
# - Modelos de linguagem n-gramas
# - HMM para sequências
# - CRF para etiquetagem
# - POS tagging automático
# - Named Entity Recognition
# - Avaliação de modelos sequenciais
#
# ---
#
# ### 🧠 **Módulo 7: Deep Learning para NLP**
# 📁 `modulo_07_deep_learning/07_deep_learning_nlp.ipynb`
#
# **🎯 Objetivos:**
# - Construir redes neurais para texto
# - Implementar RNNs, LSTMs, GRUs
# - Aplicar CNNs em classificação
# - Implementar attention mechanisms
#
# **🛠 Conteúdo Prático:**
# - LSTM completo para sentimentos
# - Arquiteturas comparadas
# - Embeddings treináveis
# - Attention visualization
# - Seq2Seq models
# - Otimização e debugging
#
# ---
#
# ### 🚀 **Módulo 8: Transformers e Modelos Pré-treinados**
# 📁 `modulo_08_transformers/08_transformers_modelos_pretreinados.ipynb`
#
# **🎯 Objetivos:**
# - Usar BERT, GPT, RoBERTa
# - Implementar fine-tuning
# - Aplicar transfer learning
# - Otimizar para produção
#
# **🛠 Conteúdo Prático:**
# - Hugging Face Transformers
# - BERT para classificação
# - Fine-tuning strategies
# - Comparação com métodos tradicionais
# - Deployment optimization
# - Model compression
#
# ---
#
# ### 🎛 **Módulo 9: Tarefas Avançadas**
# 📁 `modulo_09_tarefas_avancadas/09_tarefas_avancadas_nlp.ipynb`
#
# **🎯 Objetivos:**
# - Implementar Question Answering
# - Construir sistemas de sumarização
# - Desenvolver tradução neural
# - Aplicar topic modeling
#
# **🛠 Conteúdo Prático:**
# - QA extractivo e generativo
# - Sumarização automática
# - Neural Machine Translation
# - LDA e BERTopic
# - Chatbots inteligentes
# - Document analysis
#
# ---
#
# ### 🚀 **Módulo 10: Projetos Práticos**
# 📁 `modulo_10_projetos_praticos/10_projetos_praticos.ipynb`
#
# **🎯 Objetivos:**
# - Desenvolver projetos end-to-end
# - Criar APIs e interfaces web
# - Preparar modelos para produção
# - Construir portfólio profissional
#
# **🛠 Projetos Inclusos:**
# 1. **Sistema de Análise de Sentimentos** - E-commerce
# 2. **Chatbot Inteligente** - Atendimento ao cliente
# 3. **Sistema de Busca Semântica** - Documentos
# 4. **Sumarizador de Notícias** - Automático
# 5. **Detector de Fake News** - Classificação
#
# ---
#
# ## 🛠 Stack Tecnológico
#
# ### 📚 **Bibliotecas Principais**
# - **NLTK** - Natural Language Toolkit
# - **spaCy** - Industrial-strength NLP
# - **scikit-learn** - Machine Learning
# - **TensorFlow/Keras** - Deep Learning
# - **PyTorch** - Research-oriented DL
# - **Transformers** - State-of-the-art models
#
# ### 🌐 **Frameworks Web**
# - **Streamlit** - Interfaces rápidas
# - **FastAPI** - APIs modernas
# - **Flask** - Web apps tradicionais
# - **Gradio** - ML demos
#
# ### 📊 **Visualização**
# - **Matplotlib/Seaborn** - Plots estáticos
# - **Plotly** - Visualizações interativas
# - **WordCloud** - Nuvens de palavras
# - **Altair** - Grammar of graphics
#
# ---
#
# ## 🚀 Como Usar Este Curso
#
# ### 📋 **Pré-requisitos**
# 1. **Python 3.8+** instalado
# 2. **Jupyter Notebook** ou **JupyterLab**
# 3. **Git** para versionamento
# 4. **8GB RAM** mínimo (16GB recomendado)
#
# ### ⚙️ **Configuração Inicial**
# ```bash
# # 1. Clonar repositório
# git clone <repo-url>
# cd curso-nlp
#
# # 2. Instalar dependências
# pip install -r requirements.txt
#
# # 3. Executar setup
# python setup_curso.py
#
# # 4. Iniciar Jupyter
# jupyter lab
# ```
#
# ### 📚 **Ordem Recomendada**
# 1. **Sequencial** - Para iniciantes (Módulos 1-10)
# 2. **Por Interesse** - Para experientes (pular para módulos específicos)
# 3. **Projetos Primeiro** - Para práticos (Módulo 10 → teoria)
#
# ### 🎯 **Cronogramas Sugeridos**
#
# #### 🏃‍♂️ **Intensivo (4 semanas)**
# - **Semana 1:** Módulos 1-3 (Fundamentos)
# - **Semana 2:** Módulos 4-6 (ML Tradicional)
# - **Semana 3:** Módulos 7-8 (Deep Learning)
# - **Semana 4:** Módulos 9-10 (Avançado + Projetos)
#
# #### 🚶‍♂️ **Regular (8 semanas)**
# - **Semanas 1-2:** Módulos 1-2 (Base sólida)
# - **Semanas 3-4:** Módulos 3-4 (Análise e representação)
# - **Semanas 5-6:** Módulos 5-6 (Classificação e sequências)
# - **Semanas 7-8:** Módulos 7-10 (DL e projetos)
#
# #### 🎓 **Acadêmico (12 semanas)**
# - **Semanas 1-3:** Módulos 1-3 (Teoria profunda)
# - **Semanas 4-6:** Módulos 4-5 (ML detalhado)
# - **Semanas 7-9:** Módulos 6-7 (Sequências e DL)
# - **Semanas 10-12:** Módulos 8-10 (Estado da arte)
#
# ---
#
# ## 📈 Progressão de Competências
#
# ### 🔰 **Iniciante (Módulos 1-3)**
# - ✅ Conceitos fundamentais de NLP
# - ✅ Pré-processamento de texto
# - ✅ Análise estatística básica
# - ✅ Visualizações e insights
#
# ### 🎯 **Intermediário (Módulos 4-6)**
# - ✅ Representações vetoriais
# - ✅ Algoritmos de classificação
# - ✅ Modelos sequenciais
# - ✅ Avaliação de modelos
#
# ### 🚀 **Avançado (Módulos 7-8)**
# - ✅ Deep Learning para NLP
# - ✅ Transformers e BERT
# - ✅ Transfer Learning
# - ✅ Fine-tuning strategies
#
# ### 🏆 **Expert (Módulos 9-10)**
# - ✅ Tarefas complexas (QA, Summarization)
# - ✅ Sistemas de produção
# - ✅ APIs e deployment
# - ✅ Portfolio profissional
#
# ---
#
# ## 🎯 Objetivos de Aprendizagem
#
# Ao completar este curso, você será capaz de:
#
# ### 🔧 **Habilidades Técnicas**
# - Implementar pipelines completos de NLP
# - Escolher algoritmos apropriados para cada tarefa
# - Otimizar modelos para produção
# - Criar interfaces web para modelos ML
# - Trabalhar com modelos state-of-the-art
#
# ### 💼 **Competências Profissionais**
# - Analisar requisitos de projetos NLP
# - Comunicar resultados técnicos
# - Trabalhar com dados textuais reais
# - Desenvolver soluções escaláveis
# - Manter código de qualidade
#
# ### 🎓 **Conhecimento Teórico**
# - Fundamentos matemáticos do NLP
# - Evolução histórica da área
# - Limitações e desafios atuais
# - Tendências e futuro do NLP
# - Ética em IA e NLP
#
# ---
#
# ## 📞 Suporte e Recursos
#
# ### 🆘 **Ajuda**
# - **Issues no GitHub** - Para bugs e dúvidas
# - **Documentação** - README detalhados
# - **Exemplos extras** - Na pasta `/exemplos`
# - **Datasets** - Na pasta `/datasets`
#
# ### 📚 **Recursos Adicionais**
# - **Papers importantes** - Lista de leituras
# - **Cursos complementares** - Recomendações
# - **Comunidades** - Links úteis
# - **Ferramentas** - Software recomendado
#
# ---
#
# ## 🏁 Próximos Passos
#
# 1. **📖 Leia o README principal** - Visão geral completa
# 2. **⚙️ Execute o setup** - Configure o ambiente
# 3. **🚀 Comece pelo Módulo 1** - Fundamentos sólidos
# 4. **💪 Pratique regularmente** - Consistência é chave
# 5. **🤝 Compartilhe projetos** - Construa seu portfolio
#
# ---
#
# **🎉 Bem-vindo ao mundo do NLP! Vamos começar esta jornada incrível! 🚀**
